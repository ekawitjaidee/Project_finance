# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import datetime
# %matplotlib notebook

# %%
start = datetime.datetime(2010,1,1)
end = datetime.datetime(2011,1,1)

# %%
df = web.DataReader('AAPL','yahoo',start,end)
df = df.drop(['Open','High','Low','Volume','Adj Close'],axis=1)
pd.set_option('display.max_columns', None)
# Out:
#                 Close
# Date
# 2009-12-31   7.526072
# 2010-01-04   7.643214
# 2010-01-05   7.656428
# 2010-01-06   7.534643
# 2010-01-07   7.520714
# ...               ...
# 2010-12-27  11.595715
# 2010-12-28  11.623929
# 2010-12-29  11.617500
# 2010-12-30  11.559286
# 2010-12-31  11.520000
#
# [253 rows x 1 columns]

# %%
df[['Close']].plot(figsize=(8,8))
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
df.loc['2010-02-19','signal'] = 'buy'
df.loc['2010-02-22','signal'] = 'buy'
df.loc['2010-02-23','signal'] = 'buy'
df.loc['2010-02-24','signal'] = 'buy'

df.loc['2010-03-12','signal'] = 'sold'
df.loc['2010-03-15','signal'] = 'sold'
df.loc['2010-03-16','signal'] = 'sold'

df.loc['2010-03-19','signal'] = 'buy'
df.loc['2010-03-22','signal'] = 'buy'
df.loc['2010-03-23','signal'] = 'buy'

df.loc['2010-04-26','signal'] = 'sold'
df.loc['2010-04-27','signal'] = 'sold'
df.loc['2010-04-28','signal'] = 'sold'

df.loc['2010-05-07','signal'] = 'buy'
df.loc['2010-05-11','signal'] = 'buy'

df.loc['2010-05-14','signal'] = 'sold'
df.loc['2010-05-15','signal'] = 'sold'
df.loc['2010-05-16','signal'] = 'sold'

df.loc['2010-05-21','signal'] = 'buy'
df.loc['2010-05-22','signal'] = 'buy'
df.loc['2010-05-23','signal'] = 'buy'

df.loc['2010-06-01','signal'] = 'sold'
df.loc['2010-06-02','signal'] = 'sold'
df.loc['2010-06-03','signal'] = 'sold'

df.loc['2010-06-08','signal'] = 'buy'
df.loc['2010-06-09','signal'] = 'buy'
df.loc['2010-06-10','signal'] = 'buy'


df.loc['2010-06-18','signal'] = 'sold'
df.loc['2010-06-19','signal'] = 'sold'
df.loc['2010-06-20','signal'] = 'sold'

df.loc['2010-07-02','signal'] = 'buy'
df.loc['2010-07-03','signal'] = 'buy'
df.loc['2010-07-04','signal'] = 'buy'
df.loc['2010-07-05','signal'] = 'buy'

df.loc['2010-07-08','signal'] = 'sold'
df.loc['2010-07-09','signal'] = 'sold'
df.loc['2010-07-10','signal'] = 'sold'

df.loc['2010-07-18','signal'] = 'buy'
df.loc['2010-07-19','signal'] = 'buy'
df.loc['2010-07-20','signal'] = 'buy'

df.loc['2010-08-03','signal'] = 'sold'
df.loc['2010-08-04','signal'] = 'sold'
df.loc['2010-08-05','signal'] = 'sold'

df.loc['2010-08-25','signal'] = 'buy'
df.loc['2010-08-26','signal'] = 'buy'
df.loc['2010-08-27','signal'] = 'buy'

df.loc['2010-08-03','signal'] = 'sold'
df.loc['2010-08-04','signal'] = 'sold'
df.loc['2010-08-05','signal'] = 'sold'

# %%
df
# Out:
#                         Close signal
# Date
# 2009-12-31 00:00:00  7.526072    NaN
# 2010-01-04 00:00:00  7.643214    NaN
# 2010-01-05 00:00:00  7.656428    NaN
# 2010-01-06 00:00:00  7.534643    NaN
# 2010-01-07 00:00:00  7.520714    NaN
# ...                       ...    ...
# 2010-08-04                NaN   sold
# 2010-08-05                NaN   sold
# 2010-08-25                NaN    buy
# 2010-08-26                NaN    buy
# 2010-08-27                NaN    buy
#
# [283 rows x 2 columns]

# %%
df.head(60)
# Out:
#                         Close signal
# Date
# 2009-12-31 00:00:00  7.526072    NaN
# 2010-01-04 00:00:00  7.643214    NaN
# 2010-01-05 00:00:00  7.656428    NaN
# 2010-01-06 00:00:00  7.534643    NaN
# 2010-01-07 00:00:00  7.520714    NaN
# 2010-01-08 00:00:00  7.570714    NaN
# 2010-01-11 00:00:00  7.503929    NaN
# 2010-01-12 00:00:00  7.418571    NaN
# 2010-01-13 00:00:00  7.523214    NaN
# 2010-01-14 00:00:00  7.479643    NaN
# 2010-01-15 00:00:00  7.354643    NaN
# 2010-01-19 00:00:00  7.680000    NaN
# 2010-01-20 00:00:00  7.561786    NaN
# 2010-01-21 00:00:00  7.431071    NaN
# 2010-01-22 00:00:00  7.062500    NaN
# 2010-01-25 00:00:00  7.252500    NaN
# 2010-01-26 00:00:00  7.355000    NaN
# 2010-01-27 00:00:00  7.424286    NaN
# 2010-01-28 00:00:00  7.117500    NaN
# 2010-01-29 00:00:00  6.859286    NaN
# 2010-02-01 00:00:00  6.954643    NaN
# 2010-02-02 00:00:00  6.995000    NaN
# 2010-02-03 00:00:00  7.115357    NaN
# 2010-02-04 00:00:00  6.858929    NaN
# 2010-02-05 00:00:00  6.980714    NaN
# 2010-02-08 00:00:00  6.932857    NaN
# 2010-02-09 00:00:00  7.006786    NaN
# 2010-02-10 00:00:00  6.968572    NaN
# 2010-02-11 00:00:00  7.095357    NaN
# 2010-02-12 00:00:00  7.156428    NaN
# 2010-02-16 00:00:00  7.264286    NaN
# 2010-02-17 00:00:00  7.233929    NaN
# 2010-02-18 00:00:00  7.247500    NaN
# 2010-02-19 00:00:00  7.202500    buy
# 2010-02-22 00:00:00  7.157857    buy
# 2010-02-23 00:00:00  7.037857    buy
# 2010-02-24 00:00:00  7.166429    buy
# 2010-02-25 00:00:00  7.214286    NaN
# 2010-02-26 00:00:00  7.307857    NaN
# 2010-03-01 00:00:00  7.463929    NaN
# 2010-03-02 00:00:00  7.458929    NaN
# 2010-03-03 00:00:00  7.476071    NaN
# 2010-03-04 00:00:00  7.525357    NaN
# 2010-03-05 00:00:00  7.819643    NaN
# 2010-03-08 00:00:00  7.824286    NaN
# 2010-03-09 00:00:00  7.965000    NaN
# 2010-03-10 00:00:00  8.030000    NaN
# 2010-03-11 00:00:00  8.053572    NaN
# 2010-03-12 00:00:00  8.092857   sold
# 2010-03-15 00:00:00  7.994286   sold
# 2010-03-16 00:00:00  8.016071   sold
# 2010-03-17 00:00:00  8.004286    NaN
# 2010-03-18 00:00:00  8.023214    NaN
# 2010-03-19 00:00:00  7.937500    buy
# 2010-03-22 00:00:00  8.026786    buy
# 2010-03-23 00:00:00  8.155714    buy
# 2010-03-24 00:00:00  8.191786    NaN
# 2010-03-25 00:00:00  8.094643    NaN
# 2010-03-26 00:00:00  8.246428    NaN
# 2010-03-29 00:00:00  8.299643    NaN
