# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import datetime
import finplot as fplt

# %matplotlib notebook

# %%
df =pd.read_csv('Ground Truth file/KO(2010,2011).csv')
# df=df.set_index('Date')
day = datetime.datetime(df['Date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-9adf1215c7eb> in <module>
#       1 df =pd.read_csv('Ground Truth file/KO(2010,2011).csv')
#       2 # df=df.set_index('Date')
# ----> 3 day = datetime.datetime(df['Date'])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     110         if len(self) == 1:
#     111             return converter(self.iloc[0])
# --> 112         raise TypeError(f"cannot convert the series to {converter}")
#     113
#     114     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>

# %%
df['buy'] = np.where(df['Signal'] == 'buy',df['Close'],np.nan)
df['sold'] = np.where(df['Signal'] == 'sell',df['Close'],np.nan)

# %%
plt.figure(figsize=(10,8))
# plt.grid()
plt.title('Buy and Sold Signal')
plt.plot(df['Close'])
plt.plot(df['buy'],color='yellow')
plt.plot(df['sold'],color='red')
plt.ylabel('Price')
plt.xlabel('Date')
# Out:
# <img src="data:image/png;base64,..." width="998.8889153504084">
# Text(0.5, 0, 'Date')
