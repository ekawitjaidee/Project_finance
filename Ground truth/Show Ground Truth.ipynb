# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import datetime
import finplot as fplt
import glob

# %matplotlib notebook

# %%
mylist = [f for f in glob.glob("Ground Truth file/*.csv")]
mylist
# Out:
# ['Ground Truth file\\aapl.csv',
#  'Ground Truth file\\ABMD(2010,2011).csv',
#  'Ground Truth file\\ABMD(2011,2012).csv',
#  'Ground Truth file\\ABMD(2012,2013).csv',
#  'Ground Truth file\\ABMD(2013,2014).csv',
#  'Ground Truth file\\ABMD(2014,2015).csv',
#  'Ground Truth file\\ABT(2010,2011).csv',
#  'Ground Truth file\\ABT(2011,2012).csv',
#  'Ground Truth file\\ABT(2012,2013).csv',
#  'Ground Truth file\\ABT(2013,2014).csv',
#  'Ground Truth file\\ABT(2014,2015).csv',
#  'Ground Truth file\\IBM(2010,2011).csv',
#  'Ground Truth file\\KO(2010,2011).csv',
#  'Ground Truth file\\KO(2011,2012).csv',
#  'Ground Truth file\\MMM(2010,2011).csv',
#  'Ground Truth file\\MMM(2011,2012).csv',
#  'Ground Truth file\\MMM(2012,2013).csv',
#  'Ground Truth file\\MMM(2013,2014).csv',
#  'Ground Truth file\\MMM(2014,2015).csv']

# %%
df =pd.read_csv(str(mylist[11]))
# df=df.set_index('Date')
# day = datetime.datetime(df['Date'])

# %%
df['buy'] = np.where(df['Signal'] == 'buy',df['Close'],np.nan)
df['sold'] = np.where(df['Signal'] == 'sell',df['Close'],np.nan)

# %%
plt.figure(figsize=(10,8))
# plt.grid()
plt.title('Buy and Sold Signal')
plt.plot(df['Close'])
plt.plot(df['buy'],color='yellow')
plt.plot(df['sold'],color='red')
plt.ylabel('Price')
plt.xlabel('Date')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5, 0, 'Date')
